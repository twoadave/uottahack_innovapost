# %%
import folium
from folium.features import DivIcon
import pandas as pd

# function reads a file and adds the contents as tuples (containing coordinates) to a list, returns that list
def read_file(fileName):

    coords = []
    for line in pd.read_csv(fileName, encoding='utf-8', header=None, chunksize=1):
        coords.append((line.iloc[0,0], line.iloc[0,1]))
    
    return coords

# function creates and returns a numbered icon for the folium marker
def create_divcon(num):

    icon = DivIcon(icon_size=(150,36), 
                   icon_anchor=(14,40),
                   html='<div style="font-size: 18pt; color : black">' + '{:01d}'.format(num+1) + '</div>')  # styling for icon
    
    return icon

# function takes in a list of any size (at least two items) containing gps coordinates as tuples
# order: latitude, longitude
def generate_map(coorList):

    # initialize map from starting point (first tuple in list)
    m = folium.Map(location=[coorList[0][0], coorList[0][1]])

    points = []
    # create a marker for every other point in list
    for i in range(len(coorList)):
        points.append([coorList[i][0], coorList[i][1]])
        folium.Marker([coorList[i][0], coorList[i][1]],
                      icon=create_divcon(i)
                      ).add_to(m)
    
    # Uncomment this to enable polyline drawing using Google Maps (goes on road instead of straight line) - Wesley
    """
    import googlemaps 
    import polyline
    from datetime import datetime
    curDate = datetime.now()
    gmaps = googlemaps.Client(key='your_api key here')

    polyline_coords = []
    for i in range(0, len(coorList) - 1):
        result = gmaps.directions(origin = coorList[i], destination = coorList[i+1], mode='driving',units= 'metric', traffic_model='best_guess', departure_time = curDate)

        for x in result[0]['legs'][0]['steps']:
            polyline_coords.extend(polyline.decode(x['polyline']['points']))

    # add a line to connect the points
    folium.PolyLine(polyline_coords, color='blue'
                    ).add_to(m)
    """

    folium.PolyLine(points, color='blue'
                    ).add_to(m)

    return m

coords = read_file('./coords.csv')
m = generate_map(coords)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97a4b7264876f9cd8cab743002bae76c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97a4b7264876f9cd8cab743002bae76c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97a4b7264876f9cd8cab743002bae76c = L.map(
#                 &quot;map_97a4b7264876f9cd8cab743002bae76c&quot;,
#                 {
#                     center: [45.354957, -75.64506230308237],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfb5d76ebb250391279ab9f71696ce5f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_97a4b7264876f9cd8cab743002bae76c);
#
#
#             var marker_679b8a6c517c016b46fc75c37867a7e7 = L.marker(
#                 [45.354957, -75.64506230308237],
#                 {}
#             ).addTo(map_97a4b7264876f9cd8cab743002bae76c);
#
#
#             var div_icon_2040f4095d24b726ca97d232eb561942 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 18pt; color : black\&quot;\u003e1\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [14, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_679b8a6c517c016b46fc75c37867a7e7.setIcon(div_icon_2040f4095d24b726ca97d232eb561942);
#
#
#             var marker_35f1ba5fbc9845a680f7a83396f971e7 = L.marker(
#                 [45.3672374, -75.6380919],
#                 {}
#             ).addTo(map_97a4b7264876f9cd8cab743002bae76c);
#
#
#             var div_icon_c0a25dd24a326dc371539a2818e653f7 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 18pt; color : black\&quot;\u003e2\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [14, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_35f1ba5fbc9845a680f7a83396f971e7.setIcon(div_icon_c0a25dd24a326dc371539a2818e653f7);
#
#
#             var marker_3cfb27d28f50a5c7e4390f1524571627 = L.marker(
#                 [45.3774855, -75.60436369326396],
#                 {}
#             ).addTo(map_97a4b7264876f9cd8cab743002bae76c);
#
#
#             var div_icon_b8209e0eeb103a164b76982956922487 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 18pt; color : black\&quot;\u003e3\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [14, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_3cfb27d28f50a5c7e4390f1524571627.setIcon(div_icon_b8209e0eeb103a164b76982956922487);
#
#
#             var marker_235c72d3d8483bbf82a2fb0fa18b392c = L.marker(
#                 [45.4031906, -75.70438670883398],
#                 {}
#             ).addTo(map_97a4b7264876f9cd8cab743002bae76c);
#
#
#             var div_icon_9bbdf9edd0ece083e3c3454548599c61 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 18pt; color : black\&quot;\u003e4\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [14, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_235c72d3d8483bbf82a2fb0fa18b392c.setIcon(div_icon_9bbdf9edd0ece083e3c3454548599c61);
#
#
#             var marker_ad756dab81fc071282c37bac935e1a7e = L.marker(
#                 [45.364702, -75.63091190873016],
#                 {}
#             ).addTo(map_97a4b7264876f9cd8cab743002bae76c);
#
#
#             var div_icon_d678db3ccaa746a2ac887b1f20320c1f = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 18pt; color : black\&quot;\u003e5\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [14, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_ad756dab81fc071282c37bac935e1a7e.setIcon(div_icon_d678db3ccaa746a2ac887b1f20320c1f);
#
#
#             var marker_be9fffb82259b959f79cb7b236531d14 = L.marker(
#                 [45.4193955, -75.678723],
#                 {}
#             ).addTo(map_97a4b7264876f9cd8cab743002bae76c);
#
#
#             var div_icon_17fe5f1d5a27071292767aa56ed3ef5d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 18pt; color : black\&quot;\u003e6\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [14, 40], &quot;iconSize&quot;: [150, 36]});
#             marker_be9fffb82259b959f79cb7b236531d14.setIcon(div_icon_17fe5f1d5a27071292767aa56ed3ef5d);
#
#
#             var marker_29d715de949d84b287b639e5fa1b49fb = L.marker(
#                 [45.357542, -75.65673606039385],
#                 {}
#             ).addTo(map_97a4b7264876f9cd8cab743002bae76c);
#
#
#             var div_icon_0f0071f4113cb6218f02c8f613156afd = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &q
